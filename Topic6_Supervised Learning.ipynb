# %%
from sklearn import datasets
from sklearn import neighbors
from sklearn import metrics
from sklearn import linear_model
from sklearn

# %%
iris = datasets.load_iris()
iris

# %%
import pandas as pd
df = pd.DataFrame(iris.data, columns=iris.feature_names)

#df = pd.DataFrame(iris.data, columns=['sepal length (cm)'])


display(df.head())

# %%
df.iloc[:,0:4]
df.iloc[:,-1:]

# %%
x = df.iloc[: , 0:4]
y = df.iloc[: , -1:]

# %%
#knn = neighbors.KNeighborsClassifier(n_neighbors=5)

knn = linear.model.logistic.LogisticRegression()
knn.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1528661160.py in <cell line: 0>()
#       1 #knn = neighbors.KNeighborsClassifier(n_neighbors=5)
#       2
# ----> 3 knn = linear.model.logistic.LogisticRegression()
#       4 knn.fit(x,y)
#
# NameError: name 'linear' is not defined

# %%
y_pred = knn.predict(x)
y_pred
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /tmp/ipython-input-2642662610.py in <cell line: 0>()
# ----> 1 y_pred = knn.predict(x)
#       2 y_pred
#
# /usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_classification.py in predict(self, X)
#     255             Class labels for each data sample.
#     256         """
# --> 257         check_is_fitted(self, "_fit_method")
#     258         if self.weights == "uniform":
#     259             if self._fit_method == "brute" and ArgKminClassMode.is_usable_for(
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1755
#    1756     if not _is_fitted(estimator, attributes, all_or_any):
# -> 1757         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1758
#    1759
#
# NotFittedError: This KNeighborsClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
